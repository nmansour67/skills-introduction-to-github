# %% [markdown]
# <a href="https://colab.research.google.com/github/nmansour67/skills-introduction-to-github/blob/main/GenAI_Article_Prompts_Used.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prompt used for "Case 1" to generate the Digital Twin code that was used on the publicly availkable data from the study:
# Koltsova, E. M., Sorokina, M. A., Pisaryuk, A. S., Povalyaev, N. M., Ignatova, A. A., Polokhov, D. M., ... & Balandina, A. N. (2021). Hypercoagulation detected by routine and global laboratory hemostasis assays in patients with infective endocarditis. PLoS One, 16(12), e0261429.
#
# context: the purpose of this prompt is to replicate the study conducted and published, attached.
# the idea is to create a case study for educational purposes, whereby a group of physicians and nurses, are discussing a difficult case of a patient Mr. Hanna.
# the discussion environment is very supportive, collaborative, and open for new ideas and innovations.
# role: you are a senior endocrinologist, with a 20+ years of experience working at brigham womens hospital. you are a machine learning specialist with 15+ years working in collaboration of an academic medical center and microsoft machine learning division.
# task:
# 1. create the scenario of a cardiology board that summoned to discuss the case and decide on the best options for Mr. Hanna.
# 2. create a "Digital Twin" model that will help us to simulate various diagnostic options for Mr. Hanna.
# 3. generate a full python code that could create the digital twin model, and run it on google colab, using the attached Excel data.
# 4. The python code should ask us to upload the data while running the code.
# 5. the case that shall be created, including the digital twin, should be using evidence-based from the attached article. it should cite the article for scientific integrity purposes.
# format:
# the board room includes an experience cardiologist (10+ years of experience).
# a resident with expertise in creating digital twins models to solve similar problems.
# a community nurse.
# a medical student.
# environment: very educational, supportive, and embrace exchanging of opinions.

# %% [markdown]
# Prompt used for "Case 2", based on secondary data sourced from data published by article: Wagner, A., Zuniga, F., Rüesch, P., Schaffert, R., Dratva, J., & HCD Research Group. (2020). Selecting home care quality indicators based on the Resident Assessment Instrument-Home Care (RAI-HC) for Switzerland: A public health and healthcare providers' perspective. PLoS One, 15(12), e0244577.  context: the purpose of this prompt is to replicate the study conducted and published, attached.
# the idea is to create a case study for educational purposes, whereby a group of the Swiss home care professionals are discussing a case representing a pain point in their home care system, of a patient Mr. Hanna.
# the discussion environment is very supportive, collaborative, and open for new ideas and innovations.
# role: you are a senior home care professional, with a 20+ years of experience working in Switzerland home care services. you are a machine learning specialist with 15+ years working in collaboration of an academic medical center and microsoft machine learning division.
# task:
# 1. create the scenario of a patient who struggled with the home care services, and who encountered multiple adverse events.
# 2. create a "Digital Twin" model that will the Swiss home care service to simulate various solutions.
# 3. generate a full python code that could create the digital twin model, and run it on google colab, using the attached Excel data.
# 4. The python code should ask us to upload the data while running the code.
# 5. the case that shall be created, including the digital twin, should be using evidence-based from the attached article. it should cite the article for scientific integrity purposes.

# %% [markdown]
# Prompt used for "Case 3", based on secondary data sourced from the data published by article: 23.	Kalyango, E., Kananura, R. M., & Kiracho, E. E. (2021). Household preferences and willingness to pay for health insurance in Kampala City: a discrete choice experiment. Cost Effectiveness and Resource Allocation, 19(1), 21.
#
# Prompt:
# Write a complete Python script for Google Colab that performs comprehensive feature analysis on a Stata (.dta) file. The script should have 8 clearly labeled sections:
#
# Load Data – Upload a .dta file using Google Colab's file upload widget (with fallback to local path input), read it with pd.read_stata(), and print row/column counts.
# Basic Data Overview – Print dataset dimensions, memory usage, first 5 rows, data type counts, and a numbered list of all column names.
# Missing Data Analysis – Calculate and print a table of columns with missing values (count + percentage + dtype), sorted descending by missing percentage. Create a horizontal bar chart visualizing missing percentages.
# Numerical Features Analysis – Identify numeric columns, print their names and descriptive statistics. If ≤10 numeric columns, plot histograms with KDE curves. Compute and visualize a correlation heatmap (lower triangle only), then print all feature pairs with |r| > 0.7. Run IQR-based outlier detection and print a summary table.
# Categorical Features Analysis – Identify object/category columns, print a summary table (unique values, most common value, its frequency and percentage). If there are ≤6 categorical columns with ≤10 unique values each, create horizontal bar charts.
# Feature Relationships – Generate a seaborn pairplot for the first 5 numerical columns (KDE on diagonal, semi-transparent points).
# Data Quality Report – Print overall completeness %, total missing cells, duplicate row count, list of columns with >50% missing, and list of constant (zero-variance) columns.
# Export Summary – Build a formatted text summary string containing all key statistics (dataset info, data quality, numerical describe, categorical summary). Include commented-out code showing how to save it to a .txt file.
